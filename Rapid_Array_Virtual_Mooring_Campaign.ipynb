# %%
from mamma_mia import Campaign
from mamma_mia import inventory

# %%
campaign = Campaign(name="RAPID array virtual mooring",
                    description="single slocum glider deployment at a RAPID mooring",
                    verbose=True
                    )
# Out:
# 2025-11-07T09:56:40 - SUCCESS - Campaign RAPID array virtual mooring created

# %%
# create platform entity (mutable)
Churchill = inventory.create_platform_entity(entity_name="Churchill",platform="Slocum_G2",serial_number="unit_398")

# register sensor to platform
Churchill.register_sensor(sensor_type="CTD")
# register platform to the campaign for use in missions
campaign.register_platform(entity=Churchill)
# Out:
# 2025-11-07T09:56:48 - INFO - successfully created sensor data_logger on entity Churchill
# 2025-11-07T09:56:48 - SUCCESS - successfully created entity Churchill of type Slocum_G2
# 2025-11-07T09:56:48 - INFO - successfully created sensor CTD on entity Churchill
# 2025-11-07T09:56:48 - SUCCESS - Churchill successfully registered to RAPID array virtual mooring

# %%
# # # add mission
campaign.add_mission(mission_name="RAD24_01",
                     title="Churchill with CTD deployment at RAPID array mooring eb1l2n",
                     summary="single glider deployed to perform a virtual mooring flight at the eb1l2n RAPID array.",
                     platform_name="Churchill",
                     trajectory_path="data/RAPID-mooring/rapid-mooring.nc",
                     source_location="MSM",
                     mission_time_step=60,
                     apply_obs_error=True)
# Out:
# 2025-11-07T09:56:56 - INFO - setting source type to MSM
# 2025-11-07T09:56:57 - WARNING - Optional yaw parameter for trajectory not found in simulated data: No variable named ''
# 2025-11-07T09:56:57 - WARNING - Optional roll parameter for trajectory not found in simulated data: No variable named '['m_roll', 'GLIDER_ROLL']'
# 2025-11-07T09:56:57 - INFO - Platform requires NEMA coordinate conversion
# 2025-11-07T09:56:59 - INFO - Successfully converted from NEMA coordinates to decimal degrees
# 2025-11-07T09:56:59 - SUCCESS - successfully added mission RAD24_01 to campaign RAPID array virtual mooring

# %%
# build missions (search datasets, download datasets, build interpolators etc)
campaign.build_missions()
# Out:
# 2025-11-07T09:57:05 - INFO - building RAPID array virtual mooring missions
# 2025-11-07T09:57:05 - INFO - building RAD24_01
# 2025-11-07T09:57:05 - INFO - Initializing catalog
# 2025-11-07T09:57:05 - INFO - MSM source requested, building catalog
# 2025-11-07T09:57:05 - INFO - local catalog file found, reading catalog
# 2025-11-07T09:57:06 - INFO - Catalog initialized
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca1-era5v1/gn/U1y for WATERCURRENTS_U
# 2025-11-07T09:57:06 - INFO - creating new matched world noc-npd-era5/npd-eorca1-era5v1/gn/U1y for key WATERCURRENTS_U
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca1-era5v1/gn/U1m for WATERCURRENTS_U
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca1-era5v1/gn/U1y with new world noc-npd-era5/npd-eorca1-era5v1/gn/U1m
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca1-era5v1/gn/U1m with key WATERCURRENTS_U for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/U1y_4d for WATERCURRENTS_U
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca1-era5v1/gn/U1m with new world noc-npd-era5/npd-eorca025-era5v1/gn/U1y_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/U1y_4d with key WATERCURRENTS_U for field type annual_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/U1m_4d for WATERCURRENTS_U
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/U1y_4d with new world noc-npd-era5/npd-eorca025-era5v1/gn/U1m_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/U1m_4d with key WATERCURRENTS_U for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/U5d_4d for WATERCURRENTS_U
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/U1m_4d with new world noc-npd-era5/npd-eorca025-era5v1/gn/U5d_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/U5d_4d with key WATERCURRENTS_U for field type five_day_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca12-era5v1/gn/U1y_4d for WATERCURRENTS_U
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/U5d_4d with new world noc-npd-era5/npd-eorca12-era5v1/gn/U1y_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca12-era5v1/gn/U1y_4d with key WATERCURRENTS_U for field type annual_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca12-era5v1/gn/U1m_4d for WATERCURRENTS_U
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca12-era5v1/gn/U1y_4d with new world noc-npd-era5/npd-eorca12-era5v1/gn/U1m_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca12-era5v1/gn/U1m_4d with key WATERCURRENTS_U for field type monthly_mean
# 2025-11-07T09:57:06 - WARNING - None is not a supported field type
# 2025-11-07T09:57:06 - WARNING - None is not a supported field type
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca1-era5v1/gn/V1y for WATERCURRENTS_V
# 2025-11-07T09:57:06 - INFO - creating new matched world noc-npd-era5/npd-eorca1-era5v1/gn/V1y for key WATERCURRENTS_V
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca1-era5v1/gn/V1m for WATERCURRENTS_V
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca1-era5v1/gn/V1y with new world noc-npd-era5/npd-eorca1-era5v1/gn/V1m
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca1-era5v1/gn/V1m with key WATERCURRENTS_V for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/V1y_4d for WATERCURRENTS_V
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca1-era5v1/gn/V1m with new world noc-npd-era5/npd-eorca025-era5v1/gn/V1y_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/V1y_4d with key WATERCURRENTS_V for field type annual_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/V1m_4d for WATERCURRENTS_V
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/V1y_4d with new world noc-npd-era5/npd-eorca025-era5v1/gn/V1m_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/V1m_4d with key WATERCURRENTS_V for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/V5d_4d for WATERCURRENTS_V
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/V1m_4d with new world noc-npd-era5/npd-eorca025-era5v1/gn/V5d_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/V5d_4d with key WATERCURRENTS_V for field type five_day_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca12-era5v1/gn/V1y_4d for WATERCURRENTS_V
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/V5d_4d with new world noc-npd-era5/npd-eorca12-era5v1/gn/V1y_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca12-era5v1/gn/V1y_4d with key WATERCURRENTS_V for field type annual_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca12-era5v1/gn/V1m_4d for WATERCURRENTS_V
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca12-era5v1/gn/V1y_4d with new world noc-npd-era5/npd-eorca12-era5v1/gn/V1m_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca12-era5v1/gn/V1m_4d with key WATERCURRENTS_V for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca1-era5v1/gn/T1y for INSITU_TEMPERATURE
# 2025-11-07T09:57:06 - INFO - creating new matched world noc-npd-era5/npd-eorca1-era5v1/gn/T1y for key INSITU_TEMPERATURE
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca1-era5v1/gn/T1m for INSITU_TEMPERATURE
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca1-era5v1/gn/T1y with new world noc-npd-era5/npd-eorca1-era5v1/gn/T1m
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca1-era5v1/gn/T1m with key INSITU_TEMPERATURE for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/T1y_4d for INSITU_TEMPERATURE
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca1-era5v1/gn/T1m with new world noc-npd-era5/npd-eorca025-era5v1/gn/T1y_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/T1y_4d with key INSITU_TEMPERATURE for field type annual_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/T1m_4d for INSITU_TEMPERATURE
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/T1y_4d with new world noc-npd-era5/npd-eorca025-era5v1/gn/T1m_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/T1m_4d with key INSITU_TEMPERATURE for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/T5d_4d for INSITU_TEMPERATURE
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/T1m_4d with new world noc-npd-era5/npd-eorca025-era5v1/gn/T5d_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/T5d_4d with key INSITU_TEMPERATURE for field type five_day_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca12-era5v1/gn/T1y_4d for INSITU_TEMPERATURE
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/T5d_4d with new world noc-npd-era5/npd-eorca12-era5v1/gn/T1y_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca12-era5v1/gn/T1y_4d with key INSITU_TEMPERATURE for field type annual_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca12-era5v1/gn/T1m_4d for INSITU_TEMPERATURE
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca12-era5v1/gn/T1y_4d with new world noc-npd-era5/npd-eorca12-era5v1/gn/T1m_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca12-era5v1/gn/T1m_4d with key INSITU_TEMPERATURE for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca1-era5v1/gn/T1y for PRACTICAL_SALINITY
# 2025-11-07T09:57:06 - INFO - creating new matched world noc-npd-era5/npd-eorca1-era5v1/gn/T1y for key PRACTICAL_SALINITY
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca1-era5v1/gn/T1m for PRACTICAL_SALINITY
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca1-era5v1/gn/T1y with new world noc-npd-era5/npd-eorca1-era5v1/gn/T1m
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca1-era5v1/gn/T1m with key PRACTICAL_SALINITY for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/T1y_4d for PRACTICAL_SALINITY
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca1-era5v1/gn/T1m with new world noc-npd-era5/npd-eorca025-era5v1/gn/T1y_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/T1y_4d with key PRACTICAL_SALINITY for field type annual_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/T1m_4d for PRACTICAL_SALINITY
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/T1y_4d with new world noc-npd-era5/npd-eorca025-era5v1/gn/T1m_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/T1m_4d with key PRACTICAL_SALINITY for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca025-era5v1/gn/T5d_4d for PRACTICAL_SALINITY
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/T1m_4d with new world noc-npd-era5/npd-eorca025-era5v1/gn/T5d_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca025-era5v1/gn/T5d_4d with key PRACTICAL_SALINITY for field type five_day_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca12-era5v1/gn/T1y_4d for PRACTICAL_SALINITY
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca025-era5v1/gn/T5d_4d with new world noc-npd-era5/npd-eorca12-era5v1/gn/T1y_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca12-era5v1/gn/T1y_4d with key PRACTICAL_SALINITY for field type annual_mean
# 2025-11-07T09:57:06 - INFO - setting domain type to glo
# 2025-11-07T09:57:06 - INFO - setting world type to model
# 2025-11-07T09:57:06 - SUCCESS - found a match in noc-npd-era5/npd-eorca12-era5v1/gn/T1m_4d for PRACTICAL_SALINITY
# 2025-11-07T09:57:06 - INFO - found world with same variable alias, will assess which one to keep
# 2025-11-07T09:57:06 - INFO - new model is ranked higher, replacing....
# 2025-11-07T09:57:06 - INFO - replaced world noc-npd-era5/npd-eorca12-era5v1/gn/T1y_4d with new world noc-npd-era5/npd-eorca12-era5v1/gn/T1m_4d
# 2025-11-07T09:57:06 - INFO - updating noc-npd-era5/npd-eorca12-era5v1/gn/T1m_4d with key PRACTICAL_SALINITY for field type monthly_mean
# 2025-11-07T09:57:06 - INFO - getting msm world noc-npd-era5/npd-eorca12-era5v1/gn/U1m_4d_-14.88_-15.97_27.76_26.68_2023-02-01_2023-04-09.zarr
# 2025-11-07T09:57:06 - INFO - getting msm world noc-npd-era5/npd-eorca12-era5v1/gn/V1m_4d_-14.88_-15.97_27.76_26.68_2023-02-01_2023-04-09.zarr
# 2025-11-07T09:57:06 - INFO - getting msm world noc-npd-era5/npd-eorca12-era5v1/gn/T1m_4d_-14.88_-15.97_27.76_26.68_2023-02-01_2023-04-09.zarr
# 2025-11-07T09:57:06 - SUCCESS - successfully built RAD24_01
# 2025-11-07T09:57:06 - INFO - building interpolators for RAD24_01
# 2025-11-07T09:57:06 - INFO - building worlds for dataset noc-npd-era5/npd-eorca12-era5v1/gn/U1m_4d
# 2025-11-07T09:57:06 - INFO - building world for variable uo
# 2025-11-07T09:57:07 - INFO - built uo from source MSM into interpolator: WATERCURRENTS_U
# 2025-11-07T09:57:07 - INFO - building worlds for dataset noc-npd-era5/npd-eorca12-era5v1/gn/V1m_4d
# 2025-11-07T09:57:07 - INFO - building world for variable vo
# 2025-11-07T09:57:07 - INFO - built vo from source MSM into interpolator: WATERCURRENTS_V
# 2025-11-07T09:57:07 - INFO - building worlds for dataset noc-npd-era5/npd-eorca12-era5v1/gn/T1m_4d
# 2025-11-07T09:57:07 - INFO - building world for variable so_abs
# 2025-11-07T09:57:07 - INFO - built so_abs from source MSM into interpolator: PRACTICAL_SALINITY
# 2025-11-07T09:57:07 - INFO - interpolators built successfully
# 2025-11-07T09:57:07 - SUCCESS - successfully built interpolators for RAD24_01

# %%
# run/fly missions
campaign.run()
# Out:
# 2025-11-07T09:57:21 - INFO - running RAPID array virtual mooring
# 2025-11-07T09:57:21 - INFO - flying RAD24_01
# 2025-11-07T09:57:21 - INFO - flying RAD24_01 using Churchill
# 2025-11-07T09:57:21 - INFO - flying through GLIDER_DEPTH world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter GLIDER_DEPTH
# 2025-11-07T09:57:21 - WARNING - null values set in sensor specification no obs error applied
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - flying through GLIDER_PITCH world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter GLIDER_PITCH
# 2025-11-07T09:57:21 - WARNING - null values set in sensor specification no obs error applied
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - flying through GLIDER_ROLL world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter GLIDER_ROLL
# 2025-11-07T09:57:21 - WARNING - null values set in sensor specification no obs error applied
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - flying through GLIDER_HEADING world and creating interpolated data for flight
# 2025-11-07T09:57:21 - WARNING - no interpolator found for parameter GLIDER_HEADING marking parameter for removal from payload
# 2025-11-07T09:57:21 - INFO - flying through WATERCURRENTS_U world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter WATERCURRENTS_U
# 2025-11-07T09:57:21 - WARNING - null values set in sensor specification no obs error applied
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - flying through ALTITUDE world and creating interpolated data for flight
# 2025-11-07T09:57:21 - WARNING - no interpolator found for parameter ALTITUDE marking parameter for removal from payload
# 2025-11-07T09:57:21 - INFO - flying through LATITUDE world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter LATITUDE
# 2025-11-07T09:57:21 - WARNING - null values set in sensor specification no obs error applied
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - flying through LONGITUDE world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter LONGITUDE
# 2025-11-07T09:57:21 - WARNING - null values set in sensor specification no obs error applied
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - flying through WATERCURRENTS_V world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter WATERCURRENTS_V
# 2025-11-07T09:57:21 - WARNING - null values set in sensor specification no obs error applied
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - flying through TIME world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - flying through INSITU_TEMPERATURE world and creating interpolated data for flight
# 2025-11-07T09:57:21 - WARNING - no navigation aliases found for INSITU_TEMPERATURE
# 2025-11-07T09:57:21 - WARNING - no interpolator found for parameter INSITU_TEMPERATURE marking parameter for removal from payload
# 2025-11-07T09:57:21 - INFO - flying through PRACTICAL_SALINITY world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter PRACTICAL_SALINITY
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - flying through PRESSURE world and creating interpolated data for flight
# 2025-11-07T09:57:21 - INFO - converting depth data into pressure data
# 2025-11-07T09:57:21 - INFO - successfully converted depth data into pressure data
# 2025-11-07T09:57:21 - INFO - applying observation error to parameter PRESSURE
# 2025-11-07T09:57:21 - INFO - observation error application successful
# 2025-11-07T09:57:21 - INFO - removing marked GLIDER_HEADING from payload
# 2025-11-07T09:57:21 - INFO - removing marked ALTITUDE from payload
# 2025-11-07T09:57:21 - INFO - removing marked INSITU_TEMPERATURE from payload
# 2025-11-07T09:57:21 - INFO - alternative parameter field in world attributes is not None, PRACTICAL_SALINITY requires conversion from ABSOLUTE_SALINITY
# 2025-11-07T09:57:21 - WARNING - unknown conversion requested {'PRACTICAL_SALINITY': 'ABSOLUTE_SALINITY'}
# 2025-11-07T09:57:21 - ERROR - unable to convert alternative parameters {'PRACTICAL_SALINITY': 'ABSOLUTE_SALINITY'}
# 2025-11-07T09:57:21 - SUCCESS - RAD24_01 flown successfully
# 2025-11-07T09:57:21 - SUCCESS - RAPID array virtual mooring finished successfully

# %%
# visualise the results
campaign.missions["RAD24_01"].plot_trajectory()
campaign.missions["RAD24_01"].show_payload()

# %%
campaign.export()
